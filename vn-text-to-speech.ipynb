# %% [markdown]
# # Chuẩn bị data

# %%
# !git clone https://github.com/hoainhanpro/En_Vi_TextToSpeech.git
# %cd En_Vi_TextToSpeech

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()

# %%
# !conda install -c conda-forge montreal-forced-aligner=2.0.6

# %%
# !mkdir -p raw_data/infore
# !mkdir -p preprocessed_data/infore/TextGrid/infore
# !mkdir -p output/ckpt/infore
# !mkdir -p output/log/infore
# !mkdir -p output/result/infore

# %%
# Di chuyển file wav và txt từ thư mục infore_16k_denoised vào raw_data/infore
# !cp -r /kaggle/input/infore-16k-denoised/*.wav raw_data/infore/
# !cp -r /kaggle/input/infore-16k-denoised/*.txt raw_data/infore/

# Đổi tên các file .txt thành .lab (theo yêu cầu của MFA)
# !rename 's/\.txt$/.lab/' raw_data/infore/*.txt

# %% [markdown]
# # Align dữ liệu

# %%
   # !mfa train --clean -t ./temp ./raw_data/infore /kaggle/working/FastSpeech2_vi/lexicon/vi-new-lexicon.txt ./mfa/vi_new_mfa.zip
   # !mfa align -t ./temp ./raw_data/infore ./mfa/vi-new-lexicon.dict ./mfa/vi_new_mfa.zip ./preprocessed_data/infore/TextGrid/infore1
   # !python fix_align.py preprocessed_data/infore/TextGrid/infore1 preprocessed_data/infore/TextGrid/infore/

# %% [markdown]
# ### Nén dữ liệu -> tải về lỡ có bị dừng session còn cứu được

# %%
# Nén với mức độ nén tối đa
# !cd /kaggle/working && zip -9 -r preprocessed_data_max.zip preprocessed_data
# Out:
# updating: preprocessed_data/ (stored 0%)
# updating: preprocessed_data/infore/ (stored 0%)
# updating: preprocessed_data/infore/val.txt (deflated 64%)
# updating: preprocessed_data/infore/speakers.json (stored 0%)
# updating: preprocessed_data/infore/duration/ (stored 0%)
# updating: preprocessed_data/infore/stats.json (deflated 28%)
# updating: preprocessed_data/infore/energy/ (stored 0%)
# updating: preprocessed_data/infore/mel/ (stored 0%)
# updating: preprocessed_data/infore/TextGrid/ (stored 0%)
# updating: preprocessed_data/infore/TextGrid/infore08692.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore11321.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore11226.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore12828.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore14485.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore04559.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore07752.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore08765.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore14762.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore09880.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore14926.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore06194.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore00223.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore03006.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore13905.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore05519.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore04830.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore09002.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore09090.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore02997.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore07262.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore10421.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore09812.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore11871.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore07907.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore00050.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore14473.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore04405.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore08788.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore07451.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore11445.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore00902.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore10964.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore02063.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore09219.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore01633.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore08769.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore02725.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore13330.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore04314.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore05307.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore09507.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore14197.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore06001.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore13363.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore11194.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore12867.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore08489.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore02572.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore13632.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore04426.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore05234.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore01132.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore13008.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore11159.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore08061.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore01039.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore06228.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore11813.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore08124.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore04488.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore14265.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore10951.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore08296.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore04246.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore08424.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore10155.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore03407.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore00895.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore06484.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore02220.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore11548.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore11702.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore10316.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore00032.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore01959.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore00544.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore13834.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore06106.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore03289.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore03887.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore06138.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore08328.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore05575.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore09413.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore08091.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore02705.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore06706.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore12933.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore04661.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore06204.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore14553.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore04706.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore14545.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore06709.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore13523.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore09494.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore03802.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore10904.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore14102.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore00302.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore10476.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore07887.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore04620.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore12290.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore08583.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore12306.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore11649.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore07959.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore09524.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore03615.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore00059.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore14426.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore07845.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore09934.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore11378.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore02520.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore11948.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore04030.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore08919.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore04605.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore02639.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore00752.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore04437.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore00852.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore04482.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore06669.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore08358.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore08390.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore05952.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore14752.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore05949.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore02973.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore10601.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore07908.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore10444.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore07226.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore03538.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore06217.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore00298.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore04570.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore11638.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore07530.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore07495.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore12200.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore03013.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore13543.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore11882.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore05406.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore09744.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore07167.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore06683.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore03005.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore02956.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore01812.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore02473.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore10344.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore01247.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore03025.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore04034.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore14324.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore01204.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore12219.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore01898.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore04664.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore01359.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore09554.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore03528.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore05818.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore10247.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore08038.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore12841.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore04169.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore07075.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore13299.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore04696.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore08508.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore01347.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore10727.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore11483.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore14512.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore11091.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore12609.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore11246.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore04968.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore07179.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore03379.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore09523.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore05453.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore06969.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore03816.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore08984.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore03663.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore07610.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore02845.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore04145.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore13277.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore00661.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore12131.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore02567.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore09361.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore12906.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore00209.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore01845.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore02932.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore12909.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore04503.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore00793.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore00174.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore05941.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore10017.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore09072.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore14655.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore12492.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore03694.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore11271.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore03123.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore05542.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore11763.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore11039.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore11732.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore05083.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore07047.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore06589.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore02372.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore02431.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore03281.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore02599.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore11169.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore00484.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore11209.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore06080.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore08223.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore00911.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore09098.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore06321.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore08766.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore03993.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore04296.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore13318.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore12368.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore04852.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore01027.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore06206.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore06697.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore05951.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore14609.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore07952.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore07450.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore06347.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore02004.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore00226.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore02387.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore12265.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore04876.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore12369.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore02008.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore02156.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore04448.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore03192.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore02591.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore04673.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore09529.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore11671.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore04135.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore03090.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore11831.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore14773.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore09103.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore05023.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore10283.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore14912.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore04151.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore13326.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore04253.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore08932.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore13789.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore02865.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore07957.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore14330.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore07921.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore08512.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore14206.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore13687.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore13963.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore05193.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore10702.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore13723.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore00220.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore07709.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore10839.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore07439.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore12800.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore13150.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore07546.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore03940.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore09357.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore01550.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore10826.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore13396.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore07915.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore08478.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore04684.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore13772.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore08297.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore02230.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore11742.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore11248.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore05924.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore05283.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore12951.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore14882.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore01459.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore03574.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore05869.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore03922.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore08056.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore13603.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore07187.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore00192.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore03558.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore02987.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore11687.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore04201.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore12172.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore04631.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore13223.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore04359.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore07093.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore11520.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore08778.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore06806.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore05845.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore00676.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore11931.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore11263.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore01136.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore00801.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore05127.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore06667.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore02338.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore02450.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore09142.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore12329.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore11916.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore13372.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore08248.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore00619.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore12402.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore00970.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore02598.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore02133.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore13739.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore12624.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore14795.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore00615.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore08267.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore07039.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore07578.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore06716.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore08192.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore01278.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore14706.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore08712.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore07218.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore12476.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore01213.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore14028.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore10430.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore12311.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore12189.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore08915.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore13325.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore07882.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore10340.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore00515.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore11812.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore14270.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore01606.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore01264.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore04569.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore10262.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore12782.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore08738.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore05028.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore08687.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore11055.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore03737.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore08065.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore11302.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore06892.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore00799.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore05440.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore02720.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore05805.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore05789.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore09106.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore07867.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore03636.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore02175.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore07596.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore05381.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore07342.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore04755.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore01725.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore00170.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore13833.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore04125.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore06719.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore07753.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore02991.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore08628.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore01304.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore05036.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore14597.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore13343.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore05099.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore04123.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore07147.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore08307.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore08309.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore01195.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore04903.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore04770.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore07108.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore05064.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore10586.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore10578.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore05358.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore03238.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore02609.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore01355.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore02575.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore11758.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore10569.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore01710.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore08731.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore10643.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore08801.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore11928.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore14247.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore03962.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore00327.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore05866.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore00153.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore12235.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore12708.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore01521.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore07221.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore11611.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore08889.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore12357.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore04591.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore04748.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore08071.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore09148.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore02979.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore04396.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore08359.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore08509.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore06661.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore00253.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore08544.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore07507.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore03327.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore13222.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore12780.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore10847.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore04699.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore09611.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore06540.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore06459.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore01545.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore02244.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore11299.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore11405.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore09637.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore06632.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore04809.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore09163.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore03151.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore11609.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore08406.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore02108.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore12444.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore01231.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore03087.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore04905.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore04841.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore06059.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore06434.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore04021.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore07041.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore02803.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore08950.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore06063.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore12747.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore07261.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore09512.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore05066.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore02899.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore02461.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore06952.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore10352.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore07288.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore09052.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore00352.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore06970.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore11855.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore01340.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore03648.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore03668.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore02120.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore01778.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore07738.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore02002.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore01595.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore02946.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore14225.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore04146.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore03362.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore02528.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore04196.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore07854.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore05666.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore12617.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore05762.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore08721.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore14640.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore08080.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore00137.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore14803.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore10836.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore11804.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore11901.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore11567.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore14564.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore06732.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore00635.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore09017.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore03074.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore03915.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore02199.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore13693.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore14319.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore00806.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore13404.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore14461.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore14682.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore06479.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore13309.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore05541.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore14649.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore11821.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore14160.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore00841.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore06383.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore05903.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore07294.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore01068.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore06366.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore12112.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore11811.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore01616.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore02858.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore10123.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore03483.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore00709.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore13005.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore00273.TextGrid (deflated 88%)
# updating: preprocessed_data/infore/TextGrid/infore14728.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore09900.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore09392.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore13377.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore12450.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore02390.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore00493.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore11779.TextGrid (deflated 85%)
# updating: preprocessed_data/infore/TextGrid/infore03972.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore03421.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore06681.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore09703.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore11128.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore00225.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore02303.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore04235.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore08195.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore08475.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore13419.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore00336.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore13097.TextGrid (deflated 87%)
# updating: preprocessed_data/infore/TextGrid/infore12889.TextGrid (deflated 86%)
# updating: preprocessed_data/infore/TextGrid/infore00720.TextGrid (deflated 86%)
# ...
#   adding: preprocessed_data/infore/mel/infore-mel-14485.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-14445.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-12544.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-10765.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-13595.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-11134.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-12105.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-09547.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-06871.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-10856.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-00426.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-04858.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-09542.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-03545.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-11954.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-07579.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-04462.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-13188.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-11598.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-03356.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-08850.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-01444.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-14916.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-00522.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-12599.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-01782.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-05911.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-14865.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-00892.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-14868.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-13075.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-02164.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-02476.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-01362.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-13943.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-06637.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-10288.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-07229.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-08718.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-09963.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-00655.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-09815.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-08912.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-06066.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-01856.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-06946.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-14447.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-00448.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-04591.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-07309.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-02229.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-09527.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-04495.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-00596.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-06088.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-03461.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-02036.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-02841.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-05107.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-05219.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-11902.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-13835.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-04270.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-08091.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-13232.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-13963.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-11189.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-00414.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-06761.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-02041.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-08113.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-07777.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-11292.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-14112.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-02594.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-06726.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-06595.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-03951.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-04122.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-06420.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-12418.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-05001.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-12990.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-08517.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-03156.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-13286.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-09236.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-11647.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-06312.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-10279.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-03772.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-02309.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-09827.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-11967.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-14820.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-01243.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-09192.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-00333.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-02564.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-08219.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-08369.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-11757.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-11340.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-04501.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-14702.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-12124.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-02977.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-01280.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-09541.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-12230.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-06754.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-08163.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-08427.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-10451.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-05036.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-00321.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-01152.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-01469.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-07597.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-14847.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-06945.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-11986.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-07242.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-03596.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-01296.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-01685.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-01463.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-04126.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-03484.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-01604.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-12542.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-14319.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-04815.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-06551.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-14825.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-11760.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-00220.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-01574.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-05720.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-14737.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-09409.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-06580.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-01890.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-09847.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-07783.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-03707.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-00379.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-03883.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-06430.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-01823.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-00275.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-07588.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-07739.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-00410.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-00902.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-00667.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-06334.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-05688.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-02920.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-06394.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-03244.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-13430.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-08188.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-00977.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-03274.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-07202.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-12933.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-07722.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-08473.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-04050.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-02182.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-07190.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-02341.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-03805.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-05021.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-03948.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-07349.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-10147.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-14696.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-09101.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-00397.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-09059.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-07715.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-04162.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-09337.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-01545.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-06760.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-09670.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-09970.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-06400.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-02211.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-14262.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-04205.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-07902.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-04644.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-12470.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-06853.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-11591.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-07744.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-02149.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-06204.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-08530.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-10119.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-03055.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-14804.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-07694.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-11680.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-00635.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-09523.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-07628.npy (deflated 11%)
#   adding: preprocessed_data/infore/mel/infore-mel-04506.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-08351.npy (deflated 12%)
#   adding: preprocessed_data/infore/mel/infore-mel-01879.npy

# %%
# Kiểm tra kích thước file
# !ls -lh /kaggle/working/preprocessed_data_max.zip
# Out:
# -rw-r--r-- 1 root root 1.9G Mar 19 19:36 /kaggle/working/preprocessed_data_max.zip

# %% [markdown]
# # Tiền xử lý dữ liệu

# %%
# Sử dụng URL raw chính xác từ GitHub
# !wget -O /kaggle/working/FastSpeech2_vi/preprocessor/preprocessor.py https://raw.githubusercontent.com/sp1007/FastSpeech2_vi/master/preprocessor/preprocessor.py
# Out:
# --2025-03-19 17:43:35--  https://raw.githubusercontent.com/sp1007/FastSpeech2_vi/master/preprocessor/preprocessor.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11020 (11K) [text/plain]
# Saving to: ‘/kaggle/working/FastSpeech2_vi/preprocessor/preprocessor.py’
#
# /kaggle/working/Fas 100%[===================>]  10.76K  --.-KB/s    in 0.001s
#
# 2025-03-19 17:43:35 (12.9 MB/s) - ‘/kaggle/working/FastSpeech2_vi/preprocessor/preprocessor.py’ saved [11020/11020]

# %%
# %%writefile /kaggle/working/FastSpeech2_vi/preprocessor/preprocessor.py
import os
import random
import json

import tgt
import librosa
import numpy as np
import pyworld as pw
from scipy.interpolate import interp1d
from sklearn.preprocessing import StandardScaler
from tqdm import tqdm

import audio as Audio


class Preprocessor:
    def __init__(self, config):
        self.config = config
        # Đường dẫn tuyệt đối cho raw_data
        self.in_dir = "/kaggle/working/raw_data"
        # Đường dẫn tuyệt đối cho preprocessed_data
        self.out_dir = "/kaggle/working/preprocessed_data/infore"
        self.val_size = config["preprocessing"]["val_size"]
        self.sampling_rate = config["preprocessing"]["audio"]["sampling_rate"]
        self.hop_length = config["preprocessing"]["stft"]["hop_length"]

        assert config["preprocessing"]["pitch"]["feature"] in [
            "phoneme_level",
            "frame_level",
        ]
        assert config["preprocessing"]["energy"]["feature"] in [
            "phoneme_level",
            "frame_level",
        ]
        self.pitch_phoneme_averaging = (
            config["preprocessing"]["pitch"]["feature"] == "phoneme_level"
        )
        self.energy_phoneme_averaging = (
            config["preprocessing"]["energy"]["feature"] == "phoneme_level"
        )

        self.pitch_normalization = config["preprocessing"]["pitch"]["normalization"]
        self.energy_normalization = config["preprocessing"]["energy"]["normalization"]

        self.STFT = Audio.stft.TacotronSTFT(
            config["preprocessing"]["stft"]["filter_length"],
            config["preprocessing"]["stft"]["hop_length"],
            config["preprocessing"]["stft"]["win_length"],
            config["preprocessing"]["mel"]["n_mel_channels"],
            config["preprocessing"]["audio"]["sampling_rate"],
            config["preprocessing"]["mel"]["mel_fmin"],
            config["preprocessing"]["mel"]["mel_fmax"],
        )

    def build_from_path(self):
        os.makedirs((os.path.join(self.out_dir, "mel")), exist_ok=True)
        os.makedirs((os.path.join(self.out_dir, "pitch")), exist_ok=True)
        os.makedirs((os.path.join(self.out_dir, "energy")), exist_ok=True)
        os.makedirs((os.path.join(self.out_dir, "duration")), exist_ok=True)

        print("🔍 Bắt đầu xử lý dữ liệu...")
        out = list()
        n_frames = 0
        pitch_scaler = StandardScaler()
        energy_scaler = StandardScaler()
        
        # Biến theo dõi dữ liệu và thống kê
        has_pitch_data = False
        has_energy_data = False
        total_files = 0
        successful_files = 0
        missing_textgrid = 0
        other_errors = 0

        # Compute pitch, energy, duration, and mel-spectrogram
        speakers = {"infore": 0}
        
        # Lấy danh sách file wav từ thư mục raw_data/infore
        wav_dir = os.path.join(self.in_dir, "infore")
        wav_files = [f for f in os.listdir(wav_dir) if f.endswith('.wav')]
        
        print(f"📊 Tổng số file wav: {len(wav_files)}")
        
        # Lấy danh sách file TextGrid
        textgrid_dir = os.path.join(self.out_dir, "TextGrid")
        textgrid_files = [f for f in os.listdir(textgrid_dir) if f.endswith('.TextGrid')]
        print(f"📊 Tổng số file TextGrid: {len(textgrid_files)}")
        
        # Kiểm tra thư mục phụ infore
        infore_dir = os.path.join(textgrid_dir, "infore")
        if os.path.exists(infore_dir):
            infore_files = [f for f in os.listdir(infore_dir) if f.endswith('.TextGrid')]
            print(f"📊 Số file TextGrid trong thư mục infore: {len(infore_files)}")
        
        # Hiển thị một số tên file TextGrid để kiểm tra định dạng
        if len(textgrid_files) > 0:
            print(f"🔍 Một số tên file TextGrid: {textgrid_files[:5]}")
        
        for wav_name in tqdm(wav_files):
            total_files += 1
            basename = wav_name.split(".")[0]
            
            # Kiểm tra các định dạng tên TextGrid khác nhau
            tg_formats = [
                # TextGrid có tiền tố "infore" + basename
                ("infore" + basename, os.path.join(self.out_dir, "TextGrid", "infore{}.TextGrid".format(basename))),
                # TextGrid trong thư mục infore
                (basename, os.path.join(self.out_dir, "TextGrid", "infore", "{}.TextGrid".format(basename))),
                # TextGrid có tên giống basename
                (basename, os.path.join(self.out_dir, "TextGrid", "{}.TextGrid".format(basename)))
            ]
            
            tg_found = False
            for tg_basename, tg_path in tg_formats:
                if os.path.exists(tg_path):
                    tg_found = True
                    print(f"✅ Tìm thấy TextGrid cho {basename}: {tg_path}")
                    ret = self.process_utterance("infore", basename, tg_basename, tg_path)
                    if ret is None:
                        other_errors += 1
                        print(f"❌ Xử lý thất bại: {basename}")
                        continue
                    else:
                        info, pitch, energy, n = ret
                        successful_files += 1
                        print(f"✅ Xử lý thành công: {basename}")
                    out.append(info)

                    if len(pitch) > 0:
                        pitch_scaler.partial_fit(pitch.reshape((-1, 1)))
                        has_pitch_data = True
                    if len(energy) > 0:
                        energy_scaler.partial_fit(energy.reshape((-1, 1)))
                        has_energy_data = True

                    n_frames += n
                    break
            
            if not tg_found:
                print(f"❌ Không tìm thấy TextGrid cho {basename}")
                missing_textgrid += 1

        print("\n📊 THỐNG KÊ XỬ LÝ:")
        print(f"Tổng số file wav: {total_files}")
        print(f"Số file xử lý thành công: {successful_files}")
        print(f"Số file thiếu TextGrid: {missing_textgrid}")
        print(f"Số file lỗi xử lý khác: {other_errors}")

        print("\n🔄 Tính toán thống kê...")
        # Perform normalization if necessary
        if self.pitch_normalization:
            if has_pitch_data:
                pitch_mean = pitch_scaler.mean_[0]
                pitch_std = pitch_scaler.scale_[0]
            else:
                print("⚠️ Không tìm thấy dữ liệu pitch. Sử dụng giá trị mặc định.")
                pitch_mean = 0
                pitch_std = 1
        else:
            # A numerical trick to avoid normalization...
            pitch_mean = 0
            pitch_std = 1
            
        if self.energy_normalization:
            if has_energy_data:
                energy_mean = energy_scaler.mean_[0]
                energy_std = energy_scaler.scale_[0]
            else:
                print("⚠️ Không tìm thấy dữ liệu energy. Sử dụng giá trị mặc định.")
                energy_mean = 0
                energy_std = 1
        else:
            energy_mean = 0
            energy_std = 1

        # Kiểm tra thư mục có file nào không trước khi chuẩn hóa
        pitch_dir = os.path.join(self.out_dir, "pitch")
        energy_dir = os.path.join(self.out_dir, "energy")
        
        pitch_files = os.listdir(pitch_dir) if os.path.exists(pitch_dir) else []
        energy_files = os.listdir(energy_dir) if os.path.exists(energy_dir) else []
        print(f"📊 Số file pitch: {len(pitch_files)}")
        print(f"📊 Số file energy: {len(energy_files)}")
        
        if len(pitch_files) > 0:
            pitch_min, pitch_max = self.normalize(pitch_dir, pitch_mean, pitch_std)
        else:
            print("⚠️ Không tìm thấy file pitch để chuẩn hóa.")
            pitch_min, pitch_max = 0.0, 1.0
            
        if len(energy_files) > 0:
            energy_min, energy_max = self.normalize(energy_dir, energy_mean, energy_std)
        else:
            print("⚠️ Không tìm thấy file energy để chuẩn hóa.")
            energy_min, energy_max = 0.0, 1.0

        # Save files
        with open(os.path.join(self.out_dir, "speakers.json"), "w") as f:
            f.write(json.dumps(speakers))

        with open(os.path.join(self.out_dir, "stats.json"), "w") as f:
            stats = {
                "pitch": [
                    float(pitch_min),
                    float(pitch_max),
                    float(pitch_mean),
                    float(pitch_std),
                ],
                "energy": [
                    float(energy_min),
                    float(energy_max),
                    float(energy_mean),
                    float(energy_std),
                ],
            }
            f.write(json.dumps(stats))

        print(
            "⏱️ Tổng thời lượng dữ liệu: {} giờ".format(
                n_frames * self.hop_length / self.sampling_rate / 3600
            )
        )

        random.shuffle(out)
        out = [r for r in out if r is not None]

        # Hiển thị số lượng dữ liệu trong tập train và val
        print(f"📊 Số mẫu trong tập train: {len(out) - self.val_size}")
        print(f"📊 Số mẫu trong tập validation: {min(self.val_size, len(out))}")

        # Write metadata
        with open(os.path.join(self.out_dir, "train.txt"), "w", encoding="utf-8") as f:
            for m in out[self.val_size :]:
                f.write(m + "\n")
        with open(os.path.join(self.out_dir, "val.txt"), "w", encoding="utf-8") as f:
            for m in out[: self.val_size]:
                f.write(m + "\n")

        return out

    def process_utterance(self, speaker, basename, tg_basename=None, tg_path=None):
        try:
            # Nếu không cung cấp tg_basename, mặc định là basename
            if tg_basename is None:
                tg_basename = basename
                
            # Chỉ định chính xác đường dẫn tới file wav và lab
            wav_path = os.path.join(self.in_dir, "infore", "{}.wav".format(basename))
            text_path = os.path.join(self.in_dir, "infore", "{}.lab".format(basename))
            
            # Sử dụng tg_path nếu được cung cấp, ngược lại tạo đường dẫn
            if tg_path is None:
                tg_path = os.path.join(self.out_dir, "TextGrid", "{}.TextGrid".format(tg_basename))

            # Kiểm tra tất cả các file có tồn tại không
            if not os.path.exists(wav_path):
                print(f"❌ Không tìm thấy file wav: {wav_path}")
                return None
                
            if not os.path.exists(text_path):
                print(f"❌ Không tìm thấy file lab: {text_path}")
                return None
                
            if not os.path.exists(tg_path):
                print(f"❌ Không tìm thấy file TextGrid: {tg_path}")
                return None

            # Get alignments
            textgrid = tgt.io.read_textgrid(tg_path)
            phone, duration, start, end = self.get_alignment(
                textgrid.get_tier_by_name("phones")
            )
                
            text = "{" + " ".join(phone) + "}"
            if start >= end:
                print(f"❌ Thời gian không hợp lệ: start={start}, end={end}")
                return None

            # Read and trim wav files
            wav, _ = librosa.load(wav_path)
            wav = wav[
                int(self.sampling_rate * start) : int(self.sampling_rate * end)
            ].astype(np.float32)

            # Read raw text
            with open(text_path, "r", encoding='utf-8') as f:
                raw_text = f.readline().strip("\n")

            # Compute fundamental frequency
            pitch, t = pw.dio(
                wav.astype(np.float64),
                self.sampling_rate,
                frame_period=self.hop_length / self.sampling_rate * 1000,
            )
            pitch = pw.stonemask(wav.astype(np.float64), pitch, t, self.sampling_rate)

            pitch = pitch[: sum(duration)]
            if np.sum(pitch != 0) <= 1:
                print(f"❌ Không đủ giá trị pitch cho {basename} (số giá trị khác 0: {np.sum(pitch != 0)})")
                return None

            # Compute mel-scale spectrogram and energy
            mel_spectrogram, energy = Audio.tools.get_mel_from_wav(wav, self.STFT)
            mel_spectrogram = mel_spectrogram[:, : sum(duration)]
            energy = energy[: sum(duration)]

            if self.pitch_phoneme_averaging:
                # Khởi tạo pitch_phoneme
                pitch_phoneme = np.zeros(len(duration))
                
                # perform linear interpolation
                nonzero_ids = np.where(pitch != 0)[0]
                if len(nonzero_ids) > 0:  # Thêm kiểm tra để tránh lỗi
                    interp_fn = interp1d(
                        nonzero_ids,
                        pitch[nonzero_ids],
                        fill_value=(pitch[nonzero_ids[0]], pitch[nonzero_ids[-1]]),
                        bounds_error=False,
                    )
                    pitch = interp_fn(np.arange(0, len(pitch)))

                    # Phoneme-level average
                    pos = 0
                    for i, d in enumerate(duration):
                        if d > 0:
                            pitch_phoneme[i] = np.mean(pitch[pos : pos + d])
                        else:
                            pitch_phoneme[i] = 0
                        pos += d
                    pitch = pitch_phoneme

            if self.energy_phoneme_averaging:
                # Khởi tạo energy_phoneme
                energy_phoneme = np.zeros(len(duration))
                
                # Phoneme-level average
                pos = 0
                for i, d in enumerate(duration):
                    if d > 0:
                        energy_phoneme[i] = np.mean(energy[pos : pos + d])
                    else:
                        energy_phoneme[i] = 0
                    pos += d
                energy = energy_phoneme

            # Save files
            dur_filename = "{}-duration-{}.npy".format(speaker, basename)
            np.save(os.path.join(self.out_dir, "duration", dur_filename), duration)

            pitch_filename = "{}-pitch-{}.npy".format(speaker, basename)
            np.save(os.path.join(self.out_dir, "pitch", pitch_filename), pitch)

            energy_filename = "{}-energy-{}.npy".format(speaker, basename)
            np.save(os.path.join(self.out_dir, "energy", energy_filename), energy)

            mel_filename = "{}-mel-{}.npy".format(speaker, basename)
            np.save(
                os.path.join(self.out_dir, "mel", mel_filename),
                mel_spectrogram.T,
            )

            return (
                "|".join([basename, speaker, text, raw_text]),
                self.remove_outlier(pitch),
                self.remove_outlier(energy),
                mel_spectrogram.shape[1],
            )
        except Exception as e:
            print(f"❌ Lỗi khi xử lý {basename}: {str(e)}")
            import traceback
            traceback.print_exc()
            return None

    def get_alignment(self, tier):
        sil_phones = ["sil", "sp", "spn"]

        phones = []
        durations = []
        start_time = 0
        end_time = 0
        end_idx = 0
        for t in tier._objects:
            s, e, p = t.start_time, t.end_time, t.text

            # Trim leading silences
            if phones == []:
                if p in sil_phones:
                    continue
                else:
                    start_time = s

            if p not in sil_phones:
                # For ordinary phones
                phones.append(p)
                end_time = e
                end_idx = len(phones)
            else:
                # For silent phones
                phones.append(p)

            durations.append(
                int(
                    np.round(e * self.sampling_rate / self.hop_length)
                    - np.round(s * self.sampling_rate / self.hop_length)
                )
            )

        # Trim tailing silences
        phones = phones[:end_idx]
        durations = durations[:end_idx]

        return phones, durations, start_time, end_time

    def remove_outlier(self, values):
        values = np.array(values)
        p25 = np.percentile(values, 25)
        p75 = np.percentile(values, 75)
        lower = p25 - 1.5 * (p75 - p25)
        upper = p75 + 1.5 * (p75 - p25)
        normal_indices = np.logical_and(values > lower, values < upper)

        return values[normal_indices]

    def normalize(self, in_dir, mean, std):
        max_value = np.finfo(np.float64).min
        min_value = np.finfo(np.float64).max
        for filename in os.listdir(in_dir):
            filename = os.path.join(in_dir, filename)
            values = (np.load(filename) - mean) / std
            np.save(filename, values)

            max_value = max(max_value, max(values))
            min_value = min(min_value, min(values))

        return min_value, max_value
# Out:
# Overwriting /kaggle/working/FastSpeech2_vi/preprocessor/preprocessor.py

# %%
# !nvidia-smi
# Out:
# Wed Mar 19 18:30:26 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.03              Driver Version: 560.35.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8              9W /   70W |       1MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   41C    P8              9W /   70W |       1MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu124

# %%
import torch
print(torch.__version__)           
print(torch.cuda.is_available())   
print(torch.version.cuda)          
print(torch.cuda.device_count())   
print(torch.cuda.get_device_name(0))
# Out:
# 2.6.0+cu124
# True
# 12.4
# 2
# Tesla T4

# %%
# !python /kaggle/working/FastSpeech2_vi/preprocess.py /kaggle/working/FastSpeech2_vi/config/infore/preprocess.yaml

# %% [markdown]
# # Train model

# %%
with open('/kaggle/working/FastSpeech2_vi/config/infore/preprocess.yaml', 'r') as file:
    content = file.read()
    
# Thay đổi đường dẫn corpus_path để phù hợp với Kaggle
content = content.replace('./input/infore', './raw_data/infore')
    
with open('/kaggle/working/FastSpeech2_vi/config/infore/preprocess.yaml', 'w') as file:
    file.write(content)

# %%
# Thêm code để lưu checkpoint vào thư mục output của Kaggle
with open('/kaggle/working/FastSpeech2_vi/train.py', 'r') as file:
    content = file.read()
    
# Thêm code để lưu checkpoint định kỳ vào thư mục output của Kaggle
content = content.replace(
    'if step % save_step == 0:',
    'if step % save_step == 0:\n                    # Lưu checkpoint vào thư mục output của Kaggle\n                    kaggle_output_path = "/kaggle/working/checkpoints"\n                    os.makedirs(kaggle_output_path, exist_ok=True)\n                    torch.save(\n                        {\n                            "model": model.module.state_dict(),\n                            "optimizer": optimizer._optimizer.state_dict(),\n                        },\n                        os.path.join(\n                            kaggle_output_path,\n                            "{}.pth.tar".format(step),\n                        ),\n                    )'
)
    
with open('/kaggle/working/FastSpeech2_vi/train.py', 'w') as file:
    file.write(content)

# %%
# !pip install tensorboard

# %%
# !pip install unidecode

# %%
# !pip install inflect
# Out:
# Collecting inflect
#   Downloading inflect-7.5.0-py3-none-any.whl.metadata (24 kB)
# Collecting more_itertools>=8.5.0 (from inflect)
#   Downloading more_itertools-10.6.0-py3-none-any.whl.metadata (37 kB)
# Collecting typeguard>=4.0.1 (from inflect)
#   Downloading typeguard-4.4.2-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: typing_extensions>=4.10.0 in /usr/local/lib/python3.10/site-packages (from typeguard>=4.0.1->inflect) (4.12.2)
# Downloading inflect-7.5.0-py3-none-any.whl (35 kB)
# Downloading more_itertools-10.6.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 kB 4.3 MB/s eta 0:00:00
# Downloading typeguard-4.4.2-py3-none-any.whl (35 kB)
# Installing collected packages: typeguard, more_itertools, inflect
# Successfully installed inflect-7.5.0 more_itertools-10.6.0 typeguard-4.4.2

# %%
ls -la /kaggle/working/preprocessed_data/infore/mel | wc -l
# Out:
# 14762

# %%
# %%writefile /kaggle/working/FastSpeech2_vi/utils/model.py
import os
import json

import torch
import numpy as np
import hifigan  # Đảm bảo có dòng import này

from .tools import to_device, log, synth_one_sample
from model import FastSpeech2, ScheduledOptim


def get_model(args, configs, device, train=False):
    (preprocess_config, model_config, train_config) = configs

    model = FastSpeech2(preprocess_config, model_config).to(device)
    if args.restore_step:
        ckpt_path = os.path.join(
            train_config["path"]["ckpt_path"],
            "{}.pth.tar".format(args.restore_step),
        )
        ckpt = torch.load(ckpt_path)
        model.load_state_dict(ckpt["model"])

    if train:
        scheduled_optim = ScheduledOptim(
            model, train_config, model_config, args.restore_step
        )
        if args.restore_step:
            scheduled_optim.load_state_dict(ckpt["optimizer"])
        model.train()
        return model, scheduled_optim

    model.eval()
    model.requires_grad_ = False
    return model


def get_param_num(model):
    num_param = sum(param.numel() for param in model.parameters())
    return num_param


def get_vocoder(config, device):
    name = config["vocoder"]["model"]
    speaker = config["vocoder"]["speaker"]

    if name == "MelGAN":
        if speaker == "LJSpeech":
            vocoder = torch.hub.load(
                "descriptinc/melgan-neurips", "load_melgan", "linda_johnson"
            )
        elif speaker == "universal":
            vocoder = torch.hub.load(
                "descriptinc/melgan-neurips", "load_melgan", "multi_speaker"
            )
        vocoder.mel2wav.eval()
        vocoder.mel2wav.to(device)
    elif name == "HiFi-GAN":
        # Sửa đường dẫn để sử dụng đường dẫn tuyệt đối
        config_path = os.path.join("/kaggle/working/FastSpeech2_vi", "hifigan", "config.json")
        with open(config_path, "r") as f:
            config = json.load(f)
        config = hifigan.AttrDict(config)
        vocoder = hifigan.Generator(config)
        if speaker == "LJSpeech":
            ckpt_path = os.path.join("/kaggle/working/FastSpeech2_vi", "hifigan", "generator_LJSpeech.pth.tar")
        elif speaker == "universal":
            ckpt_path = os.path.join("/kaggle/working/FastSpeech2_vi", "hifigan", "generator_universal.pth.tar")
        ckpt = torch.load(ckpt_path)
        vocoder.load_state_dict(ckpt["generator"])
        vocoder.eval()
        vocoder.remove_weight_norm()
        vocoder.to(device)

    return vocoder


def vocoder_infer(mels, vocoder, model_config, preprocess_config, lengths=None):
    name = model_config["vocoder"]["model"]
    with torch.no_grad():
        if name == "MelGAN":
            wavs = vocoder.inverse(mels / np.log(10))
        elif name == "HiFi-GAN":
            wavs = vocoder(mels).squeeze(1)

    wav_reconstruction = []
    for i in range(len(mels)):
        if lengths is not None:
            wav_reconstruction.append(
                wavs[i, : lengths[i] * preprocess_config["preprocessing"]["stft"]["hop_length"]]
                .cpu()
                .numpy()
            )
        else:
            wav_reconstruction.append(wavs[i].cpu().numpy())

    return wav_reconstruction
# Out:
# Overwriting /kaggle/working/FastSpeech2_vi/utils/model.py

# %%
# %%writefile /kaggle/working/FastSpeech2_vi/dataset.py
import json
import math
import os

import numpy as np
from torch.utils.data import Dataset

from text import text_to_sequence
from utils.tools import pad_1D, pad_2D


class Dataset(Dataset):
    def __init__(
        self, filename, preprocess_config, train_config, sort=False, drop_last=False
    ):
        self.dataset_name = preprocess_config["dataset"]
        self.preprocessed_path = preprocess_config["path"]["preprocessed_path"]
        self.cleaners = preprocess_config["preprocessing"]["text"]["text_cleaners"]
        self.batch_size = train_config["optimizer"]["batch_size"]

        self.basename, self.speaker, self.text, self.raw_text = self.process_meta(
            filename
        )
        with open(os.path.join(self.preprocessed_path, "speakers.json")) as f:
            self.speaker_map = json.load(f)
        self.sort = sort
        self.drop_last = drop_last

    def __len__(self):
        return len(self.text)

    def __getitem__(self, idx):
        basename = self.basename[idx]
        speaker = self.speaker[idx]
        speaker_id = self.speaker_map[speaker]
        raw_text = self.raw_text[idx]
        phone = np.array(text_to_sequence(self.text[idx], self.cleaners))
        
        # Đường dẫn tới các file đặc trưng
        mel_path = os.path.join(
            self.preprocessed_path,
            "mel",
            "{}-mel-{}.npy".format(speaker, basename),
        )
        pitch_path = os.path.join(
            self.preprocessed_path,
            "pitch",
            "{}-pitch-{}.npy".format(speaker, basename),
        )
        energy_path = os.path.join(
            self.preprocessed_path,
            "energy",
            "{}-energy-{}.npy".format(speaker, basename),
        )
        duration_path = os.path.join(
            self.preprocessed_path,
            "duration",
            "{}-duration-{}.npy".format(speaker, basename),
        )

        # Đọc và chuyển đổi dữ liệu sang float32
        mel = np.load(mel_path).astype(np.float32)
        pitch = np.load(pitch_path).astype(np.float32)
        energy = np.load(energy_path).astype(np.float32)
        duration = np.load(duration_path).astype(np.float32)

        sample = {
            "id": basename,
            "speaker": speaker_id,
            "text": phone,
            "raw_text": raw_text,
            "mel": mel,
            "pitch": pitch,
            "energy": energy,
            "duration": duration,
        }

        return sample

    def process_meta(self, filename):
        with open(
            os.path.join(self.preprocessed_path, filename), "r", encoding="utf-8"
        ) as f:
            name = []
            speaker = []
            text = []
            raw_text = []
            for line in f.readlines():
                n, s, t, r = line.strip("\n").split("|")
                name.append(n)
                speaker.append(s)
                text.append(t)
                raw_text.append(r)
            return name, speaker, text, raw_text

    def reprocess(self, data, idxs):
        ids = [data[idx]["id"] for idx in idxs]
        speakers = [data[idx]["speaker"] for idx in idxs]
        texts = [data[idx]["text"] for idx in idxs]
        raw_texts = [data[idx]["raw_text"] for idx in idxs]
        mels = [data[idx]["mel"] for idx in idxs]
        pitches = [data[idx]["pitch"] for idx in idxs]
        energies = [data[idx]["energy"] for idx in idxs]
        durations = [data[idx]["duration"] for idx in idxs]

        text_lens = np.array([text.shape[0] for text in texts])
        mel_lens = np.array([mel.shape[0] for mel in mels])

        speakers = np.array(speakers)
        texts = pad_1D(texts)
        mels = pad_2D(mels)
        pitches = pad_1D(pitches)
        energies = pad_1D(energies)
        durations = pad_1D(durations)

        return (
            ids,
            raw_texts,
            speakers,
            texts,
            text_lens,
            max(text_lens),
            mels,
            mel_lens,
            max(mel_lens),
            pitches,
            energies,
            durations,
        )

    def collate_fn(self, data):
        data_size = len(data)

        if self.sort:
            len_arr = np.array([d["text"].shape[0] for d in data])
            idx_arr = np.argsort(-len_arr)
        else:
            idx_arr = np.arange(data_size)

        tail = idx_arr[len(idx_arr) - (len(idx_arr) % self.batch_size) :]
        idx_arr = idx_arr[: len(idx_arr) - (len(idx_arr) % self.batch_size)]
        idx_arr = idx_arr.reshape((-1, self.batch_size)).tolist()
        if not self.drop_last and len(tail) > 0:
            idx_arr += [tail.tolist()]

        output = list()
        for idx in idx_arr:
            output.append(self.reprocess(data, idx))

        return output


class TextDataset(Dataset):
    def __init__(self, filepath, preprocess_config):
        self.cleaners = preprocess_config["preprocessing"]["text"]["text_cleaners"]

        self.basename, self.speaker, self.text, self.raw_text = self.process_meta(
            filepath
        )
        with open(
            os.path.join(
                preprocess_config["path"]["preprocessed_path"], "speakers.json"
            )
        ) as f:
            self.speaker_map = json.load(f)

    def __len__(self):
        return len(self.text)

    def __getitem__(self, idx):
        basename = self.basename[idx]
        speaker = self.speaker[idx]
        speaker_id = self.speaker_map[speaker]
        raw_text = self.raw_text[idx]
        phone = np.array(text_to_sequence(self.text[idx], self.cleaners))

        return (basename, speaker_id, phone, raw_text)

    def process_meta(self, filename):
        with open(filename, "r", encoding="utf-8") as f:
            name = []
            speaker = []
            text = []
            raw_text = []
            for line in f.readlines():
                n, s, t, r = line.strip("\n").split("|")
                name.append(n)
                speaker.append(s)
                text.append(t)
                raw_text.append(r)
            return name, speaker, text, raw_text

    def collate_fn(self, data):
        ids = [d[0] for d in data]
        speakers = np.array([d[1] for d in data])
        texts = [d[2] for d in data]
        raw_texts = [d[3] for d in data]
        text_lens = np.array([text.shape[0] for text in texts])

        texts = pad_1D(texts)

        return ids, raw_texts, speakers, texts, text_lens, max(text_lens)
# Out:
# Overwriting /kaggle/working/FastSpeech2_vi/dataset.py

# %%
# %%writefile /kaggle/working/FastSpeech2_vi/config/infore/train.yaml
# optimizer:
#   batch_size: 16
#   group_size: 1
#   betas: [0.9, 0.98]  # Thêm dòng này
#   eps: 0.000000001  # Thêm cả eps nếu cần
#   weight_decay: 0.0  # Thêm cả weight_decay nếu cần
#   grad_clip_thresh: 1.0  # Thêm cả giới hạn gradient clipping
#   grad_acc_step: 1  # Thêm số bước tích lũy gradient
#   warm_up_step: 4000  # Thêm số bước khởi động
#   anneal_steps: [300000, 400000, 500000]  # Thêm các bước giảm learning rate
#   anneal_rate: 0.3  # Thêm tỉ lệ giảm learning rate
#
# path:
#   ckpt_path: "./output/ckpt/infore"
#   log_path: "./output/log/infore"
#   result_path: "./output/result/infore"
#
# step:
#   total_step: 10000  # Đã giảm từ 900,000 xuống 10,000
#   log_step: 100
#   synth_step: 1000
#   val_step: 1000
#   save_step: 1000
#
# seed: 1234  # Thêm seed để kết quả tái tạo được
# Out:
# Overwriting /kaggle/working/FastSpeech2_vi/config/infore/train.yaml

# %%
# %%writefile /kaggle/working/FastSpeech2_vi/config/infore/train.yaml
# path:
#   ckpt_path: "/kaggle/working/output/ckpt/infore"
#   log_path: "/kaggle/working/output/log/infore"
#   result_path: "/kaggle/working/output/result/infore"
# optimizer:
#   batch_size: 16
#   betas: [0.9, 0.98]
#   eps: 0.000000001
#   weight_decay: 0.0
#   grad_clip_thresh: 1.0
#   grad_acc_step: 1
#   warm_up_step: 4000
#   anneal_steps: [300000, 400000, 500000]
#   anneal_rate: 0.3
# step:
#   total_step: 100000  # Giảm xuống để huấn luyện nhanh hơn
#   log_step: 100
#   synth_step: 1000
#   val_step: 1000
#   save_step: 1000
# Out:
# Overwriting /kaggle/working/FastSpeech2_vi/config/infore/train.yaml

# %%
# %%writefile /kaggle/working/FastSpeech2_vi/config/infore/preprocess.yaml
# dataset: "infore"
#
# path:
#   corpus_path: "/kaggle/working/raw_data/infore"
#   lexicon_path: "/kaggle/working/FastSpeech2_vi/lexicon/vi-new-lexicon.txt"
#   raw_path: "/kaggle/working/raw_data/"
#   preprocessed_path: "/kaggle/working/preprocessed_data/infore"
#
# preprocessing:
#   val_size: 512
#   text:
#     text_cleaners: ["vietnamese_cleaners"]
#     language: "vi"
#   audio:
#     sampling_rate: 22050
#     max_wav_value: 32768.0
#   stft:
#     filter_length: 1024
#     hop_length: 256
#     win_length: 1024
#   mel:
#     n_mel_channels: 80
#     mel_fmin: 0
#     mel_fmax: 8000 # please set to 8000 for HiFi-GAN vocoder, set to null for MelGAN vocoder
#   pitch:
#     feature: "phoneme_level" # support 'phoneme_level' or 'frame_level'
#     normalization: True
#   energy:
#     feature: "phoneme_level" # support 'phoneme_level' or 'frame_level'
#     normalization: True
# Out:
# Overwriting /kaggle/working/FastSpeech2_vi/config/infore/preprocess.yaml

# %%
# !python /kaggle/working/FastSpeech2_vi/train.py -p /kaggle/working/FastSpeech2_vi/config/infore/preprocess.yaml -m /kaggle/working/FastSpeech2_vi/config/infore/model.yaml -t /kaggle/working/FastSpeech2_vi/config/infore/train.yaml
# Out:
# Prepare training ...
# Number of FastSpeech2 Parameters: 35272513
# /usr/local/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# Removing weight norm...
# Training:   0%|                                       | 0/10000 [00:00<?, ?it/s]
# Training:   0%|                             | 5/10000 [00:02<1:09:56,  2.38it/s]
# Training:   0%|                               | 9/10000 [00:04<55:32,  3.00it/s]
# Training:   0%|                              | 13/10000 [00:05<47:32,  3.50it/s]
# Training:   0%|                              | 17/10000 [00:06<45:35,  3.65it/s]
# Training:   0%|                              | 21/10000 [00:07<48:51,  3.40it/s]
# Training:   0%|                              | 25/10000 [00:08<46:32,  3.57it/s]
# Training:   0%|                              | 29/10000 [00:10<47:21,  3.51it/s]
# Training:   0%|                              | 33/10000 [00:11<47:00,  3.53it/s]
# Training:   0%|                              | 37/10000 [00:12<48:38,  3.41it/s]
# Training:   0%|                              | 41/10000 [00:13<49:38,  3.34it/s]
# Training:   0%|▏                             | 45/10000 [00:15<47:55,  3.46it/s]
# Training:   0%|▏                             | 49/10000 [00:16<47:55,  3.46it/s]
# Training:   1%|▏                             | 53/10000 [00:17<47:23,  3.50it/s]
# Training:   1%|▏                             | 57/10000 [00:18<46:05,  3.60it/s]
# Training:   1%|▏                             | 61/10000 [00:20<45:57,  3.60it/s]
# Training:   1%|▏                             | 65/10000 [00:21<45:59,  3.60it/s]
# Training:   1%|▏                             | 69/10000 [00:22<48:45,  3.39it/s]
# Training:   1%|▏                             | 73/10000 [00:23<48:20,  3.42it/s]
# Training:   1%|▏                             | 77/10000 [00:25<46:52,  3.53it/s]
# Training:   1%|▏                             | 81/10000 [00:26<46:25,  3.56it/s]
# Training:   1%|▎                             | 85/10000 [00:27<48:55,  3.38it/s]
# Training:   1%|▎                             | 89/10000 [00:29<51:11,  3.23it/s]
# Training:   1%|▎                             | 93/10000 [00:30<47:27,  3.48it/s]
# Training:   1%|▎                             | 97/10000 [00:31<47:45,  3.46it/s]
#
# Step 100/10000, Total Loss: 12.3027, Mel Loss: 4.8796, Mel PostNet Loss: 4.5611, Pitch Loss: 1.3542, Energy Loss: 1.0359, Duration Loss: 0.4720
# Training:   1%|▎                            | 100/10000 [00:32<52:15,  3.16it/s]
# Training:   1%|▎                            | 101/10000 [00:32<52:51,  3.12it/s]
# Training:   1%|▎                            | 105/10000 [00:34<48:15,  3.42it/s]
# Training:   1%|▎                            | 109/10000 [00:35<50:38,  3.26it/s]
# Training:   1%|▎                            | 113/10000 [00:36<48:02,  3.43it/s]
# Training:   1%|▎                            | 117/10000 [00:38<52:24,  3.14it/s]
# Training:   1%|▎                          | 118/10000 [00:38<1:01:14,  2.69it/s]

# %% [markdown]
# # Lưu checkpoint đề phòng timeout

# %%
# Lưu checkpoint vào Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Sao chép checkpoint từ thư mục làm việc của Kaggle vào Google Drive
# !cp -r /kaggle/working/checkpoints/* /content/drive/MyDrive/fastspeech2_checkpoints/

# %%
# # Tạo notebook mới và tải lại checkpoint
# !mkdir -p output/ckpt/infore
# !cp /content/drive/MyDrive/fastspeech2_checkpoints/100000.pth.tar output/ckpt/infore/

# # Tiếp tục huấn luyện
# !python train.py --restore_step 100000 -p config/infore/preprocess.yaml -m config/infore/model.yaml -t config/infore/train.yaml

# %% [markdown]
# Thử nghiệm model

# %%
# !python synthesize.py --text "Xin chào, tôi là trợ lý ảo tiếng Việt được huấn luyện bởi Hoài Nhân" --restore_step 100000 --mode single -p /kaggle/working/FastSpeech2_vi/config/infore/preprocess.yaml -m /kaggle/working/FastSpeech2_vi/config/infore/model.yaml -t /kaggle/working/FastSpeech2_vi/config/infore/train.yaml
